# %% [markdown]
# # Linear Regression and Temperature

# %% [markdown]
# In this notebook, we'll look at using linear regression to study changes in temperature.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# ## Getting our data

# %% [markdown]
# We'll be getting data from [North America Land Data Assimilation System (NLDAS)](https://wonder.cdc.gov/NASA-NLDAS.html), which provides the daily average temperature from 1979-2011 for the United States.

# %% [markdown]
# For the next step, you will need to choose some settings in the data request form. These are:
#
# - GroupBy: Month Day, Year
# - Your State
# - Export Results (check box)
# - Show Zero Values (check box)

# %% [markdown]
# >1) Download the data for your home state (or state of your choosing) and upload it to M2 in your work directory.

# %% [markdown]
# # Loading our data

# %%
df = pd.read_csv('North America Land Data Assimilation System (NLDAS) Daily Air Temperatures and Heat Index (1979-2011).txt',delimiter='\t',skipfooter=14,engine='python')

# %%
df
# Out:
#        Notes Month Day, Year Month Day, Year Code    State  State Code  \
# 0        NaN    Jan 01, 1979           1979/01/01  Georgia        13.0
# 1      Total    Jan 01, 1979           1979/01/01      NaN         NaN
# 2        NaN    Jan 02, 1979           1979/01/02  Georgia        13.0
# 3      Total    Jan 02, 1979           1979/01/02      NaN         NaN
# 4        NaN    Jan 03, 1979           1979/01/03  Georgia        13.0
# ...      ...             ...                  ...      ...         ...
# 24102    NaN    Dec 30, 2011           2011/12/30  Georgia        13.0
# 24103  Total    Dec 30, 2011           2011/12/30      NaN         NaN
# 24104    NaN    Dec 31, 2011           2011/12/31  Georgia        13.0
# 24105  Total    Dec 31, 2011           2011/12/31      NaN         NaN
# 24106  Total             NaN                  NaN      NaN         NaN
#
#        Avg Daily Max Air Temperature (F)
# 0                                  69.77
# ...

# %% [markdown]
# ### Clean the data

# %% [markdown]
# >2) Drop any rows that have the value "Total" in the Notes column, then drop the Notes column

# %%
df_2 = df[df['Notes']!='Total']
df_2
# Out:
#       Notes Month Day, Year Month Day, Year Code    State  State Code  \
# 0       NaN    Jan 01, 1979           1979/01/01  Georgia        13.0
# 2       NaN    Jan 02, 1979           1979/01/02  Georgia        13.0
# 4       NaN    Jan 03, 1979           1979/01/03  Georgia        13.0
# 6       NaN    Jan 04, 1979           1979/01/04  Georgia        13.0
# 8       NaN    Jan 05, 1979           1979/01/05  Georgia        13.0
# ...     ...             ...                  ...      ...         ...
# 24096   NaN    Dec 27, 2011           2011/12/27  Georgia        13.0
# 24098   NaN    Dec 28, 2011           2011/12/28  Georgia        13.0
# 24100   NaN    Dec 29, 2011           2011/12/29  Georgia        13.0
# 24102   NaN    Dec 30, 2011           2011/12/30  Georgia        13.0
# 24104   NaN    Dec 31, 2011           2011/12/31  Georgia        13.0
#
#        Avg Daily Max Air Temperature (F)
# 0                                  69.77
# 2                                  60.20
# ...

# %%
NoNotes=df_2.drop(['Notes'], axis=1)
NoNotes
# Out:
#       Month Day, Year Month Day, Year Code    State  State Code  \
# 0        Jan 01, 1979           1979/01/01  Georgia        13.0
# 2        Jan 02, 1979           1979/01/02  Georgia        13.0
# 4        Jan 03, 1979           1979/01/03  Georgia        13.0
# 6        Jan 04, 1979           1979/01/04  Georgia        13.0
# 8        Jan 05, 1979           1979/01/05  Georgia        13.0
# ...               ...                  ...      ...         ...
# 24096    Dec 27, 2011           2011/12/27  Georgia        13.0
# 24098    Dec 28, 2011           2011/12/28  Georgia        13.0
# 24100    Dec 29, 2011           2011/12/29  Georgia        13.0
# 24102    Dec 30, 2011           2011/12/30  Georgia        13.0
# 24104    Dec 31, 2011           2011/12/31  Georgia        13.0
#
#        Avg Daily Max Air Temperature (F)
# 0                                  69.77
# 2                                  60.20
# 4                                  30.47
# ...

# %% [markdown]
# >3) Make a column called Date that is in the pandas datetime format

# %%
NoNotes['Date_Fixed'] = pd.to_datetime(NoNotes['Month Day, Year'],errors='raise')
NoNotes[['Avg Daily Max Air Temperature (F)','Month Day, Year','Date_Fixed']]
# Out:
#        Avg Daily Max Air Temperature (F) Month Day, Year Date_Fixed
# 0                                  69.77    Jan 01, 1979 1979-01-01
# 2                                  60.20    Jan 02, 1979 1979-01-02
# 4                                  30.47    Jan 03, 1979 1979-01-03
# 6                                  39.70    Jan 04, 1979 1979-01-04
# 8                                  47.89    Jan 05, 1979 1979-01-05
# ...                                  ...             ...        ...
# 24096                              57.76    Dec 27, 2011 2011-12-27
# 24098                              52.93    Dec 28, 2011 2011-12-28
# 24100                              56.85    Dec 29, 2011 2011-12-29
# 24102                              63.96    Dec 30, 2011 2011-12-30
# 24104                              65.19    Dec 31, 2011 2011-12-31
#
# [12053 rows x 3 columns]

# %% [markdown]
# >4) Make columns for 'Year', 'Month', and 'Day' by splitting the column 'Month Day, Year'

# %%
NoNotes['Date_Int'] = NoNotes['Date_Fixed'].astype(int)/10e10
NoNotes
# Out:
#       Month Day, Year Month Day, Year Code    State  State Code  \
# 0        Jan 01, 1979           1979/01/01  Georgia        13.0
# 2        Jan 02, 1979           1979/01/02  Georgia        13.0
# 4        Jan 03, 1979           1979/01/03  Georgia        13.0
# 6        Jan 04, 1979           1979/01/04  Georgia        13.0
# 8        Jan 05, 1979           1979/01/05  Georgia        13.0
# ...               ...                  ...      ...         ...
# 24096    Dec 27, 2011           2011/12/27  Georgia        13.0
# 24098    Dec 28, 2011           2011/12/28  Georgia        13.0
# 24100    Dec 29, 2011           2011/12/29  Georgia        13.0
# 24102    Dec 30, 2011           2011/12/30  Georgia        13.0
# 24104    Dec 31, 2011           2011/12/31  Georgia        13.0
#
#        Avg Daily Max Air Temperature (F) Date_Fixed    Date_Int
# 0                                  69.77 1979-01-01   2839968.0
# 2                                  60.20 1979-01-02   2840832.0
# ...

# %%
NoNotes[['Year', 'Month','Day']] = NoNotes["Date_Fixed"].apply(lambda x: pd.Series(str(x).split("-")))
print(NoNotes)
# Out:
#       Month Day, Year Month Day, Year Code    State  State Code  \
# 0        Jan 01, 1979           1979/01/01  Georgia        13.0
# 2        Jan 02, 1979           1979/01/02  Georgia        13.0
# 4        Jan 03, 1979           1979/01/03  Georgia        13.0
# 6        Jan 04, 1979           1979/01/04  Georgia        13.0
# 8        Jan 05, 1979           1979/01/05  Georgia        13.0
# ...               ...                  ...      ...         ...
# 24096    Dec 27, 2011           2011/12/27  Georgia        13.0
# 24098    Dec 28, 2011           2011/12/28  Georgia        13.0
# 24100    Dec 29, 2011           2011/12/29  Georgia        13.0
# 24102    Dec 30, 2011           2011/12/30  Georgia        13.0
# 24104    Dec 31, 2011           2011/12/31  Georgia        13.0
#
#        Avg Daily Max Air Temperature (F) Date_Fixed    Date_Int  Year Month  \
# 0                                  69.77 1979-01-01   2839968.0  1979    01
# ...

# %% [markdown]
# ## Generating a scatter plot

# %% [markdown]
# > 4) Use df.plot.scatter to plot 'Date' vs 'Avg Daily Max Air Temperature (F)'. You might want to add figsize=(50,5) as an argument to make it more clear what is happening.

# %%
NoNotes.plot.scatter(x = 'Date_Fixed', y = 'Avg Daily Max Air Temperature (F)',figsize=(50,5))
# Out:
# <AxesSubplot:xlabel='Date_Fixed', ylabel='Avg Daily Max Air Temperature (F)'>

# %% [markdown]
# >5) Describe your plot.
# The majority of my data is in temperatures between 70-80. The max is 100 and the min temperature is 10 degrees.

# %% [markdown]
# ### Adding colors for our graph

# %%
# No need to edit this unless you want to try different colors or a pattern other than colors by month

cmap = matplotlib.cm.get_cmap("nipy_spectral", len(NoNotes['Month'].unique())) # Builds a discrete color mapping using a built in matplotlib color map

c = []
for i in range(cmap.N): # Converts our discrete map into Hex Values
    rgba = cmap(i)
    c.append(matplotlib.colors.rgb2hex(rgba))

NoNotes['color']=[c[int(i-1)] for i in NoNotes['Month'].astype(int)] # Adds a column to our dataframe with the color we want for each row

# %% [markdown]
# >6) Make the same plot as 4) but add color by adding the argument c=df\['color'\] to our plotting command.

# %%
NoNotes.plot.scatter(x = 'Date_Fixed', y = 'Avg Daily Max Air Temperature (F)',figsize=(50,5), color='pink')
# Out:
# <AxesSubplot:xlabel='Date_Fixed', ylabel='Avg Daily Max Air Temperature (F)'>

# %% [markdown]
# ## Pick a subset of the data

# %% [markdown]
# >7) Select a 6 month period from the data. # Hint use logic and pd.datetime(YYYY, MM, DD)

# %%
NoNotes['Date_Fixed'] = pd.to_datetime(NoNotes['Date_Fixed'])
start_date = pd.datetime(1999, 1, 1)
end_date = pd.datetime(1999, 7, 1)
selected_data = NoNotes[(NoNotes['Date_Fixed'] >= start_date) & (NoNotes['Date_Fixed'] <= end_date)]
selected_data
# Out:
#       Month Day, Year Month Day, Year Code    State  State Code  \
# 14610    Jan 01, 1999           1999/01/01  Georgia        13.0
# 14612    Jan 02, 1999           1999/01/02  Georgia        13.0
# 14614    Jan 03, 1999           1999/01/03  Georgia        13.0
# 14616    Jan 04, 1999           1999/01/04  Georgia        13.0
# 14618    Jan 05, 1999           1999/01/05  Georgia        13.0
# ...               ...                  ...      ...         ...
# 14964    Jun 27, 1999           1999/06/27  Georgia        13.0
# 14966    Jun 28, 1999           1999/06/28  Georgia        13.0
# 14968    Jun 29, 1999           1999/06/29  Georgia        13.0
# 14970    Jun 30, 1999           1999/06/30  Georgia        13.0
# 14972    Jul 01, 1999           1999/07/01  Georgia        13.0
#
#        Avg Daily Max Air Temperature (F) Date_Fixed   Date_Int  Year Month  \
# 14610                              55.85 1999-01-01  9151488.0  1999    01
# ...

# %% [markdown]
# >8) Plot the subset using the the same code you used in 6). You can change the figsize if needed.

# %%
selected_data.plot.scatter(x = 'Date_Fixed', y = 'Avg Daily Max Air Temperature (F)',c=selected_data['color'])
# Out:
# <AxesSubplot:xlabel='Date_Fixed', ylabel='Avg Daily Max Air Temperature (F)'>

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# We are going to use a very [simple linear regression model](https://en.wikipedia.org/wiki/Simple_linear_regression). You may implement a more complex model if you wish.
#
# The method described here is called the least squares method and is defined as:
#
# $m = \frac{\sum_{i=1}^{n}(x_i-\bar{x})(y_i-\bar{y}))}{\sum_{i=1}^{n}(x_i-\bar{x})^2}$
#
# $b = \bar{y} - m\bar{x}$
#
# Where $\bar{x}$ and $\bar{y}$ are the average value of $x$ and $y$ respectively.

# %% [markdown]
# First we need to define our X and Y values.

# %%
X=selected_data['Date_Int'].values
Y=selected_data['Avg Daily Max Air Temperature (F)'].values

# %%
def lin_reg(x,y):
    x_avg = np.mean(x)
    y_avg = np.mean(y)

    num = 0
    den = 0
    for i in range(len(x)):
        num = num + (x[i] - x_avg)*(y[i] - y_avg) 
        den = den + (x[i] - x_avg)**2
    m = num / den
    b = y_avg - m*x_avg
    print (m, b)
    y_pred = m*x + b
    return y_pred

# %%
Y_pred = lin_reg(X,Y)
# Out:
# 0.0002162428923761683 -1924.501874730649

# %%
selected_data.plot.scatter(x='Date_Fixed', y='Avg Daily Max Air Temperature (F)',c=selected_data['color'])
plt.plot([min(selected_data['Date_Fixed'].values), max(selected_data['Date_Fixed'].values)], [min(Y_pred), max(Y_pred)], color='red') # best fit line
plt.show()

# %% [markdown]
# >9) What are the slope and intercept of your best fit line?

# %% [markdown]
# What are the minimum and maximum Y values of your best fit line? Is your slope positive or negative?

# %%
min_Y = Y.min()
min_Y
# Out:
# 29.71

# %%
max_Y = Y.max()
max_Y
# Out:
# 92.44

# %%
#the slope is postive

# %% [markdown]
# ## Putting it all together

# %% [markdown]
# >11) Generate a best fit line for the full data set and plot the line over top of the data.

# %%
X=NoNotes['Date_Int'].values
Y=NoNotes['Avg Daily Max Air Temperature (F)'].values

# %%
Y_pred = lin_reg(X,Y)
# Out:
# 2.889380293368249e-07 71.32050582973926

# %%
NoNotes.plot.scatter(x = 'Date_Int', y = 'Avg Daily Max Air Temperature (F)',figsize=(50,5),c=NoNotes['color'])
plt.plot([min(NoNotes['Date_Int'].values), max(NoNotes['Date_Int'].values)], [min(Y_pred), max(Y_pred)], color='red') # best fit line
plt.show()

# %% [markdown]
# >12) Is the slope positive or negative? What do you think that means?

# %%
#the slope is postive, because there is a postive correlation between the temperatures and the time of year it is. It looks like a parallel line becuase it is staying stable as the year changes.
