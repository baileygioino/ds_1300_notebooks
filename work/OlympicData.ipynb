# %%
import pandas as pd

# %%
df=pd.read_csv('athlete_events.csv')

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df2=df[['Name','Sex','Season','Year','Sport', 'Medal']].sort_values(by='Sport', ascending=True)
df2
# Out:
#                                   Name Sex  Season  Year          Sport Medal
# 214105               Hermann Schreiber   M  Summer  1936    Aeronautics  Gold
# 59184                  Martina Dubovsk   F  Winter  2014  Alpine Skiing   NaN
# 216145                Marianne Seltsam   F  Winter  1952  Alpine Skiing   NaN
# 216144                Marianne Seltsam   F  Winter  1952  Alpine Skiing   NaN
# 15326              Anne-Sophie Barthet   F  Winter  2006  Alpine Skiing   NaN
# ...                                ...  ..     ...   ...            ...   ...
# 115174                    Momir Kecman   M  Summer  1972      Wrestling   NaN
# 43200           Sin Ernesto Chen Cattn   M  Summer  1964      Wrestling   NaN
# 115161  Almat Kabdrashevich Kebispayev   M  Summer  2016      Wrestling   NaN
# 73860                 Yoshihiro Fujita   M  Summer  1984      Wrestling   NaN
# 7080            Olof Mauritz Andersson   M  Summer  1912      Wrestling   NaN
#
# [271116 rows x 6 columns]

# %%
df3=df2.dropna()
df3
# Out:
#                              Name Sex  Season  Year          Sport   Medal
# 214105          Hermann Schreiber   M  Summer  1936    Aeronautics    Gold
# 215865   Katja Seizinger (-Weber)   F  Winter  1998  Alpine Skiing    Gold
# 215864   Katja Seizinger (-Weber)   F  Winter  1998  Alpine Skiing  Bronze
# 15256            Wolfgang Bartels   M  Winter  1964  Alpine Skiing  Bronze
# 215862   Katja Seizinger (-Weber)   F  Winter  1998  Alpine Skiing    Gold
# ...                           ...  ..     ...   ...            ...     ...
# 109172    Ivar Valentin Johansson   M  Summer  1932      Wrestling    Gold
# 109173    Ivar Valentin Johansson   M  Summer  1932      Wrestling    Gold
# 109174    Ivar Valentin Johansson   M  Summer  1936      Wrestling    Gold
# 109190  Kent-Olle Tommy Johansson   M  Summer  1984      Wrestling  Silver
# 234907                Khalil Taha   M  Summer  1952      Wrestling  Bronze
#
# [39783 rows x 6 columns]

# %%
NoMale=df3[df3['Sex']!='M']
NoMale
# Out:
#                             Name Sex  Season  Year          Sport   Medal
# 215865  Katja Seizinger (-Weber)   F  Winter  1998  Alpine Skiing    Gold
# 215864  Katja Seizinger (-Weber)   F  Winter  1998  Alpine Skiing  Bronze
# 215862  Katja Seizinger (-Weber)   F  Winter  1998  Alpine Skiing    Gold
# 215858  Katja Seizinger (-Weber)   F  Winter  1994  Alpine Skiing    Gold
# 215855  Katja Seizinger (-Weber)   F  Winter  1992  Alpine Skiing  Bronze
# ...                          ...  ..     ...   ...            ...     ...
# 256851                   Wang Xu   F  Summer  2004      Wrestling    Gold
# 256591                 Wang Jiao   F  Summer  2008      Wrestling    Gold
# 89120            Kyoko Hamaguchi   F  Summer  2008      Wrestling  Bronze
# 89119            Kyoko Hamaguchi   F  Summer  2004      Wrestling  Bronze
# 265003  Elitsa Atanasova Yankova   F  Summer  2016      Wrestling  Bronze
#
# [11253 rows x 6 columns]

# %%
WinterFemale=NoMale[(NoMale['Season'] == 'Winter')&(NoMale['Sex'] == 'F')]
WinterFemale
# Out:
#                                          Name Sex  Season  Year  \
# 215865               Katja Seizinger (-Weber)   F  Winter  1998
# 215864               Katja Seizinger (-Weber)   F  Winter  1998
# 215862               Katja Seizinger (-Weber)   F  Winter  1998
# 215858               Katja Seizinger (-Weber)   F  Winter  1994
# 215855               Katja Seizinger (-Weber)   F  Winter  1992
# ...                                       ...  ..     ...   ...
# 67351        Svetlana Aleksandrovna Fedotkina   F  Winter  1994
# 134124               Catriona Ann Le May Doan   F  Winter  2002
# 265338  Irina Nikolayevna Yegorova (-Pavlova)   F  Winter  1964
# 265337  Irina Nikolayevna Yegorova (-Pavlova)   F  Winter  1964
# 198942                                Ren Hui   F  Winter  2006
#
#                 Sport   Medal
# 215865  Alpine Skiing    Gold
# 215864  Alpine Skiing  Bronze
# 215862  Alpine Skiing    Gold
# 215858  Alpine Skiing    Gold
# 215855  Alpine Skiing  Bronze
# ...

# %%
WinterMale=df3[(df3['Season'] == 'Winter')&(df3['Sex'] == 'M')]
WinterMale
# Out:
#                         Name Sex  Season  Year          Sport   Medal
# 15256       Wolfgang Bartels   M  Winter  1964  Alpine Skiing  Bronze
# 103115   Christof Innerhofer   M  Winter  2014  Alpine Skiing  Silver
# 103117   Christof Innerhofer   M  Winter  2014  Alpine Skiing  Bronze
# 213642      Othmar Schneider   M  Winter  1952  Alpine Skiing    Gold
# 213641      Othmar Schneider   M  Winter  1952  Alpine Skiing  Silver
# ...                      ...  ..     ...   ...            ...     ...
# 97271      Hans Johnny Hglin   M  Winter  1968  Speed Skating    Gold
# 86917   Sven Tomas Gustafson   M  Winter  1984  Speed Skating    Gold
# 115493         Erhard Keller   M  Winter  1968  Speed Skating    Gold
# 86918   Sven Tomas Gustafson   M  Winter  1984  Speed Skating  Silver
# 126373           Sven Kramer   M  Winter  2014  Speed Skating    Gold
#
# [3884 rows x 6 columns]

# %%
SummerFemale=NoMale[(NoMale['Season'] == 'Summer')&(NoMale['Sex'] == 'F')]
SummerFemale
# Out:
#                                                   Name Sex  Season  Year  \
# 60641   Harriet Pauline "Hettie" Dyhrenfurth (Heyman-)   F  Summer  1936
# 261210              Alison Jane Williamson (-Conaghan)   F  Summer  2004
# 66423                                      Fang Yuting   F  Summer  2012
# 262865                        Emily Woodruff (Smiley-)   F  Summer  1904
# 99507                   Matilda "Lida" Howell (Scott-)   F  Summer  1904
# ...                                                ...  ..     ...   ...
# 256851                                         Wang Xu   F  Summer  2004
# 256591                                       Wang Jiao   F  Summer  2008
# 89120                                  Kyoko Hamaguchi   F  Summer  2008
# 89119                                  Kyoko Hamaguchi   F  Summer  2004
# 265003                        Elitsa Atanasova Yankova   F  Summer  2016
#
#             Sport   Medal
# 60641    Alpinism    Gold
# 261210    Archery  Bronze
# ...

# %%
SummerMale=df3[(df3['Season'] == 'Summer')&(df3['Sex'] == 'M')]
SummerMale
# Out:
#                              Name Sex  Season  Year        Sport   Medal
# 214105          Hermann Schreiber   M  Summer  1936  Aeronautics    Gold
# 213142         Franz Xaver Schmid   M  Summer  1932     Alpinism    Gold
# 213208        Anton "Toni" Schmid   M  Summer  1932     Alpinism    Gold
# 60639     Gnter Oskar Dyhrenfurth   M  Summer  1936     Alpinism    Gold
# 193148     Richard John Priestman   M  Summer  1988      Archery  Bronze
# ...                           ...  ..     ...   ...          ...     ...
# 109172    Ivar Valentin Johansson   M  Summer  1932    Wrestling    Gold
# 109173    Ivar Valentin Johansson   M  Summer  1932    Wrestling    Gold
# 109174    Ivar Valentin Johansson   M  Summer  1936    Wrestling    Gold
# 109190  Kent-Olle Tommy Johansson   M  Summer  1984    Wrestling  Silver
# 234907                Khalil Taha   M  Summer  1952    Wrestling  Bronze
#
# [24646 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y)
plt.title('Female Summer Sports')
plt.xlabel('Sport')
plt.ylabel('Medal')
plt.show()

# %%
plt.scatter(x, y, marker="s", c="r")
plt.title('Scatter plot with marker and color change')
# Out:
# Text(0.5, 1.0, 'Scatter plot with marker and color change')

# %%
SummerFemale.plot.bar(x = 'Year', y = 'Medal', figsize=(10,20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 SummerFemale.plot.bar(x = 'Year', y = 'Medal', figsize=(10,20))
#
# File /opt/conda/lib/python3.9/site-packages/pandas/plotting/_core.py:1131, in PlotAccessor.bar(self, x, y, **kwargs)
#    1043 @Appender(
#    1044     """
#    1045     See Also
#    (...)
#    1120 @Appender(_bar_or_line_doc)
#    1121 def bar(self, x=None, y=None, **kwargs):
#    1122     """
#    1123     Vertical bar plot.
#    1124
#    (...)
#    1129     other axis represents a measured value.
#    1130     """
# -> 1131     return self(kind="bar", x=x, y=y, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/plotting/_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# ...

# %%
SummerFemale[['Name','Sex','Season','Year','Sport', 'Medal']].sort_values(by='Medal', ascending=True)

# %%
GirlBar= pd.DataFrame({'Sport':['A', 'B', 'C']})
>>> ax = df.plot.bar(x='Sport', y='Medal', rot=0)
